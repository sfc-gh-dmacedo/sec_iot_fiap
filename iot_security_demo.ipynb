# %% [markdown]
# # Demo de Segurança em IoT - AWS IoT Core
# ## MBA FIAP - Internet das Coisas
#
# ---
#
# ### 🎯 Objetivo
# Demonstrar conceitos de **segurança em IoT** usando AWS IoT Core, focando em:
# - **Autenticação Mútua TLS (mTLS)**
# - **Certificados X.509**
# - **Políticas de Acesso Granular**
# - **Criptografia em Trânsito**
# - **Princípio do Menor Privilégio**
#
# ---
